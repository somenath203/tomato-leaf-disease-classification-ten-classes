# %% [markdown]
# ## Importing all the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam 
import tensorflow_hub as hub
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the tomato dataset

# %%
dataset_directory_location = 'tomato_dataset'

# %% [markdown]
# ## Listing the directories present inside tomato dataset

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %% [markdown]
# ## Getting the training and testing directory location

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %% [markdown]
# ## Listing all the directories present inside 'train' and 'test' directory respectively

# %%
os.listdir(train_dataset_location)
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
os.listdir(test_dataset_location)
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %% [markdown]
# ## Viewing a 'tomato image with bacterial spot image'

# %%
tomato_bacterial_spot_img = os.path.join(train_dataset_location, 'Tomato___Bacterial_spot')

# %%
os.listdir(tomato_bacterial_spot_img)[:1]
# Out:
# ['00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG']

# %%
tomato_bacterial_spot_img_read = imread(os.path.join(tomato_bacterial_spot_img, '00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG'))

# %%
plt.imshow(tomato_bacterial_spot_img_read)

# %% [markdown]
# ## Getting the shape of the image

# %%
tomato_bacterial_spot_img_read.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Setting the right image shape of the image for our use case

# %%
correct_image_shape = (224, 224, 3)

# %% [markdown]
# ## Performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               rescale=1./255)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
get_mobilenet_v2_pretrained_model = hub.KerasLayer("https://www.kaggle.com/models/google/mobilenet-v2/frameworks/TensorFlow2/variations/075-224-classification/versions/2", trainable=False)

# %%
model_mobilenet_v2 = hub.KerasLayer(get_mobilenet_v2_pretrained_model, input_shape=correct_image_shape)

# %%
model.add(model_mobilenet_v2)

model.add(BatchNormalization())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_1 (KerasLayer)  (None, 1001)              2664345
#
#  batch_normalization (BatchN  (None, 1001)             4004
#  ormalization)
#
#  dense (Dense)               (None, 128)               128256
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_3 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 2,808,167
# Trainable params: 141,372
# Non-trainable params: 2,666,795
# _________________________________________________________________

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 183s 253ms/step - loss: 0.9151 - accuracy: 0.6999 - val_loss: 0.4846 - val_accuracy: 0.8410
# Epoch 2/30
# 625/625 [==============================] - 154s 247ms/step - loss: 0.5753 - accuracy: 0.8090 - val_loss: 0.4262 - val_accuracy: 0.8600
# Epoch 3/30
# 625/625 [==============================] - 147s 236ms/step - loss: 0.4905 - accuracy: 0.8340 - val_loss: 0.4046 - val_accuracy: 0.8660
# Epoch 4/30
# 625/625 [==============================] - 146s 233ms/step - loss: 0.4457 - accuracy: 0.8483 - val_loss: 0.3519 - val_accuracy: 0.8720
# Epoch 5/30
# 625/625 [==============================] - 161s 258ms/step - loss: 0.3951 - accuracy: 0.8658 - val_loss: 0.3400 - val_accuracy: 0.8910
# Epoch 6/30
# 625/625 [==============================] - 176s 281ms/step - loss: 0.3889 - accuracy: 0.8682 - val_loss: 0.3527 - val_accuracy: 0.8770
# Epoch 7/30
# 625/625 [==============================] - 161s 257ms/step - loss: 0.3756 - accuracy: 0.8718 - val_loss: 0.3389 - val_accuracy: 0.8930
# Epoch 8/30
# 625/625 [==============================] - 160s 256ms/step - loss: 0.3492 - accuracy: 0.8838 - val_loss: 0.3171 - val_accuracy: 0.8990
# Epoch 9/30
# 625/625 [==============================] - 160s 256ms/step - loss: 0.3311 - accuracy: 0.8909 - val_loss: 0.3011 - val_accuracy: 0.9040
# Epoch 10/30
# 625/625 [==============================] - 166s 266ms/step - loss: 0.3193 - accuracy: 0.8930 - val_loss: 0.3210 - val_accuracy: 0.8890
# Epoch 11/30
# 625/625 [==============================] - 159s 254ms/step - loss: 0.3046 - accuracy: 0.8967 - val_loss: 0.3014 - val_accuracy: 0.9030
# Epoch 12/30
# 625/625 [==============================] - 156s 249ms/step - loss: 0.3035 - accuracy: 0.8959 - val_loss: 0.2973 - val_accuracy: 0.9080
# Epoch 13/30
# 625/625 [==============================] - 169s 271ms/step - loss: 0.3040 - accuracy: 0.8970 - val_loss: 0.2730 - val_accuracy: 0.9090
# Epoch 14/30
# 625/625 [==============================] - 172s 275ms/step - loss: 0.2813 - accuracy: 0.9032 - val_loss: 0.2978 - val_accuracy: 0.9040
# Epoch 15/30
# 625/625 [==============================] - 149s 239ms/step - loss: 0.2719 - accuracy: 0.9060 - val_loss: 0.2712 - val_accuracy: 0.9080
# Epoch 16/30
# 625/625 [==============================] - 145s 232ms/step - loss: 0.2779 - accuracy: 0.9039 - val_loss: 0.2776 - val_accuracy: 0.9080
# Epoch 17/30
# 625/625 [==============================] - 146s 233ms/step - loss: 0.2604 - accuracy: 0.9136 - val_loss: 0.2631 - val_accuracy: 0.9070
# Epoch 18/30
# 625/625 [==============================] - 146s 234ms/step - loss: 0.2656 - accuracy: 0.9080 - val_loss: 0.2873 - val_accuracy: 0.9100
# Epoch 19/30
# 625/625 [==============================] - 158s 253ms/step - loss: 0.2667 - accuracy: 0.9090 - val_loss: 0.2604 - val_accuracy: 0.9120
# Epoch 20/30
# 625/625 [==============================] - 152s 243ms/step - loss: 0.2374 - accuracy: 0.9172 - val_loss: 0.2456 - val_accuracy: 0.9210
# Epoch 21/30
# 625/625 [==============================] - 160s 255ms/step - loss: 0.2510 - accuracy: 0.9131 - val_loss: 0.2984 - val_accuracy: 0.8950
# Epoch 22/30
# 625/625 [==============================] - 150s 240ms/step - loss: 0.2448 - accuracy: 0.9180 - val_loss: 0.2767 - val_accuracy: 0.9030
# Epoch 23/30
# 625/625 [==============================] - 148s 236ms/step - loss: 0.2359 - accuracy: 0.9181 - val_loss: 0.2882 - val_accuracy: 0.9040
# Epoch 24/30
# 625/625 [==============================] - 145s 232ms/step - loss: 0.2436 - accuracy: 0.9188 - val_loss: 0.2628 - val_accuracy: 0.9100
# Epoch 25/30
# 625/625 [==============================] - 158s 252ms/step - loss: 0.2324 - accuracy: 0.9230 - val_loss: 0.2640 - val_accuracy: 0.9060
# Epoch 26/30
# 625/625 [==============================] - 151s 241ms/step - loss: 0.2176 - accuracy: 0.9257 - val_loss: 0.2392 - val_accuracy: 0.9250
# Epoch 27/30
# 625/625 [==============================] - 159s 254ms/step - loss: 0.2255 - accuracy: 0.9203 - val_loss: 0.2517 - val_accuracy: 0.9170
# Epoch 28/30
# 625/625 [==============================] - 156s 250ms/step - loss: 0.2140 - accuracy: 0.9289 - val_loss: 0.2849 - val_accuracy: 0.9060
# Epoch 29/30
# 625/625 [==============================] - 146s 233ms/step - loss: 0.2181 - accuracy: 0.9277 - val_loss: 0.2800 - val_accuracy: 0.9090
# Epoch 30/30
# 625/625 [==============================] - 146s 234ms/step - loss: 0.2157 - accuracy: 0.9264 - val_loss: 0.2651 - val_accuracy: 0.9190

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Calculating the accuracy on training and testing data

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 625/625 [==============================] - 133s 212ms/step - loss: 0.0941 - accuracy: 0.9679
# 0.9678999781608582

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 63/63 [==============================] - 13s 210ms/step - loss: 0.2508 - accuracy: 0.9170
# 0.9169999957084656

# %% [markdown]
# ## Making prediction on sample data

# %%
sample_img_load = image.load_img('./tomato_dataset/test/Tomato___Bacterial_spot/01a3cf3f-94c1-44d5-8972-8c509d62558e___GCREC_Bact.Sp 3396.JPG', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load) / 255

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'Tomato___Bacterial_spot'

# %% [markdown]
# ## Saving the model

# %%
save_model(model, 'mobilenetv2_model')
# Out:
# WARNING:absl:Found untraced functions such as keras_layer_layer_call_fn, keras_layer_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: mobilenetv2_model\assets
# INFO:tensorflow:Assets written to: mobilenetv2_model\assets
