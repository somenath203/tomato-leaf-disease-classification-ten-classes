# %% [markdown]
# ## Importing all the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import Dense, BatchNormalization, Flatten
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the tomato dataset

# %%
dataset_directory_location = 'tomato_dataset'

# %% [markdown]
# ## Listing the directories present inside tomato dataset

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %% [markdown]
# ## Getting the training and testing directory location

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %% [markdown]
# ## Listing all the directories present inside 'train' and 'test' directory respectively

# %%
os.listdir(train_dataset_location)
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
os.listdir(test_dataset_location)
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %% [markdown]
# ## Viewing a 'tomato image with bacterial spot image'

# %%
tomato_bacterial_spot_img = os.path.join(train_dataset_location, 'Tomato___Bacterial_spot')

# %%
os.listdir(tomato_bacterial_spot_img)[:1]
# Out:
# ['00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG']

# %%
tomato_bacterial_spot_img_read = imread(os.path.join(tomato_bacterial_spot_img, '00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG'))

# %%
plt.imshow(tomato_bacterial_spot_img_read)

# %% [markdown]
# ## Getting the shape of the image

# %%
tomato_bacterial_spot_img_read.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Setting the right image shape of the image for our use case

# %%
correct_image_shape = (224, 224, 3)

# %% [markdown]
# ## Performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               preprocessing_function=preprocess_input)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
resnet50_model = ResNet50(weights='imagenet', include_top=False, input_shape=correct_image_shape)

# %%
resnet50_model.trainable = False

# %%
model.add(resnet50_model)


model.add(Flatten())


model.add(BatchNormalization())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten (Flatten)           (None, 100352)            0
#
#  batch_normalization (BatchN  (None, 100352)           401408
#  ormalization)
#
#  dense (Dense)               (None, 128)               12845184
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_3 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 36,845,866
# Trainable params: 13,057,002
# Non-trainable params: 23,788,864
# _________________________________________________________________

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 186s 258ms/step - loss: 0.8165 - accuracy: 0.7384 - val_loss: 0.3943 - val_accuracy: 0.8740
# Epoch 2/30
# 625/625 [==============================] - 152s 244ms/step - loss: 0.4283 - accuracy: 0.8609 - val_loss: 0.3031 - val_accuracy: 0.9070
# Epoch 3/30
# 625/625 [==============================] - 152s 243ms/step - loss: 0.3182 - accuracy: 0.8932 - val_loss: 0.2647 - val_accuracy: 0.9170
# Epoch 4/30
# 625/625 [==============================] - 168s 268ms/step - loss: 0.2748 - accuracy: 0.9054 - val_loss: 0.3047 - val_accuracy: 0.9080
# Epoch 5/30
# 625/625 [==============================] - 154s 247ms/step - loss: 0.2454 - accuracy: 0.9197 - val_loss: 0.2567 - val_accuracy: 0.9110
# Epoch 6/30
# 625/625 [==============================] - 156s 249ms/step - loss: 0.2113 - accuracy: 0.9310 - val_loss: 0.2327 - val_accuracy: 0.9330
# Epoch 7/30
# 625/625 [==============================] - 152s 244ms/step - loss: 0.1972 - accuracy: 0.9331 - val_loss: 0.2226 - val_accuracy: 0.9350
# Epoch 8/30
# 625/625 [==============================] - 150s 240ms/step - loss: 0.1754 - accuracy: 0.9410 - val_loss: 0.2276 - val_accuracy: 0.9250
# Epoch 9/30
# 625/625 [==============================] - 153s 245ms/step - loss: 0.1801 - accuracy: 0.9398 - val_loss: 0.2195 - val_accuracy: 0.9290
# Epoch 10/30
# 625/625 [==============================] - 146s 234ms/step - loss: 0.1692 - accuracy: 0.9445 - val_loss: 0.2613 - val_accuracy: 0.9160
# Epoch 11/30
# 625/625 [==============================] - 145s 231ms/step - loss: 0.1712 - accuracy: 0.9458 - val_loss: 0.1890 - val_accuracy: 0.9360
# Epoch 12/30
# 625/625 [==============================] - 144s 230ms/step - loss: 0.1436 - accuracy: 0.9519 - val_loss: 0.1638 - val_accuracy: 0.9510
# Epoch 13/30
# 625/625 [==============================] - 151s 241ms/step - loss: 0.1437 - accuracy: 0.9532 - val_loss: 0.2117 - val_accuracy: 0.9350
# Epoch 14/30
# 625/625 [==============================] - 162s 259ms/step - loss: 0.1312 - accuracy: 0.9569 - val_loss: 0.1968 - val_accuracy: 0.9400
# Epoch 15/30
# 625/625 [==============================] - 147s 235ms/step - loss: 0.1205 - accuracy: 0.9606 - val_loss: 0.2336 - val_accuracy: 0.9230
# Epoch 16/30
# 625/625 [==============================] - 146s 234ms/step - loss: 0.1355 - accuracy: 0.9538 - val_loss: 0.2191 - val_accuracy: 0.9370
# Epoch 17/30
# 625/625 [==============================] - 146s 233ms/step - loss: 0.1219 - accuracy: 0.9573 - val_loss: 0.2217 - val_accuracy: 0.9290
# Epoch 18/30
# 625/625 [==============================] - 144s 230ms/step - loss: 0.1049 - accuracy: 0.9665 - val_loss: 0.1852 - val_accuracy: 0.9370
# Epoch 19/30
# 625/625 [==============================] - 146s 234ms/step - loss: 0.1120 - accuracy: 0.9622 - val_loss: 0.1807 - val_accuracy: 0.9380
# Epoch 20/30
# 625/625 [==============================] - 147s 234ms/step - loss: 0.1119 - accuracy: 0.9638 - val_loss: 0.2125 - val_accuracy: 0.9370
# Epoch 21/30
# 625/625 [==============================] - 147s 235ms/step - loss: 0.0973 - accuracy: 0.9694 - val_loss: 0.1625 - val_accuracy: 0.9470
# Epoch 22/30
# 625/625 [==============================] - 146s 233ms/step - loss: 0.0988 - accuracy: 0.9664 - val_loss: 0.1931 - val_accuracy: 0.9410
# Epoch 23/30
# 625/625 [==============================] - 156s 250ms/step - loss: 0.0841 - accuracy: 0.9709 - val_loss: 0.2025 - val_accuracy: 0.9380
# Epoch 24/30
# 625/625 [==============================] - 149s 238ms/step - loss: 0.0957 - accuracy: 0.9688 - val_loss: 0.1835 - val_accuracy: 0.9430
# Epoch 25/30
# 625/625 [==============================] - 148s 237ms/step - loss: 0.0835 - accuracy: 0.9721 - val_loss: 0.1894 - val_accuracy: 0.9390
# Epoch 26/30
# 625/625 [==============================] - 149s 238ms/step - loss: 0.0769 - accuracy: 0.9721 - val_loss: 0.1768 - val_accuracy: 0.9480
# Epoch 27/30
# 625/625 [==============================] - 148s 236ms/step - loss: 0.0826 - accuracy: 0.9707 - val_loss: 0.1574 - val_accuracy: 0.9470
# Epoch 28/30
# 625/625 [==============================] - 148s 237ms/step - loss: 0.0791 - accuracy: 0.9722 - val_loss: 0.1380 - val_accuracy: 0.9580
# Epoch 29/30
# 625/625 [==============================] - 148s 237ms/step - loss: 0.0848 - accuracy: 0.9715 - val_loss: 0.1976 - val_accuracy: 0.9390
# Epoch 30/30
# 625/625 [==============================] - 149s 239ms/step - loss: 0.0716 - accuracy: 0.9763 - val_loss: 0.1637 - val_accuracy: 0.9480

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Calculating the accuracy on training and testing data

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 625/625 [==============================] - 135s 215ms/step - loss: 0.0232 - accuracy: 0.9912
# 0.9911999702453613

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1640 - accuracy: 0.9460
# 0.9459999799728394

# %% [markdown]
# ## Making prediction on sample data

# %%
sample_img_load = image.load_img('./tomato_dataset/test/Tomato___Leaf_Mold/0ac36661-a47d-47ff-8948-42edec033b87___Crnl_L.Mold 9127.JPG', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load)

# %%
sample_img_to_arr_preprocess_input = preprocess_input(sample_img_to_arr)

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr_preprocess_input, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'Tomato___Leaf_Mold'

# %% [markdown]
# ## Saving the model

# %%
save_model(model, 'resnet50_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: resnet50_model\assets
# INFO:tensorflow:Assets written to: resnet50_model\assets
