# %% [markdown]
# ## Importing all the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the tomato dataset

# %%
dataset_directory_location = 'tomato_dataset'

# %% [markdown]
# ## Listing the directories present inside tomato dataset

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %% [markdown]
# ## Getting the training and testing directory location

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %% [markdown]
# ## Listing all the directories present inside 'train' and 'test' directory respectively

# %%
os.listdir(train_dataset_location)
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
os.listdir(test_dataset_location)
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %% [markdown]
# ## Viewing a 'tomato image with bacterial spot image'

# %%
tomato_bacterial_spot_img = os.path.join(train_dataset_location, 'Tomato___Bacterial_spot')

# %%
os.listdir(tomato_bacterial_spot_img)[:1]
# Out:
# ['00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG']

# %%
tomato_bacterial_spot_img_read = imread(os.path.join(tomato_bacterial_spot_img, '00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG'))

# %%
plt.imshow(tomato_bacterial_spot_img_read)

# %% [markdown]
# ## Getting the shape of the image

# %%
tomato_bacterial_spot_img_read.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Setting the right image shape of the image for our use case

# %%
correct_image_shape = (224, 224, 3)

# %% [markdown]
# ## Performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               rescale=1./255)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=correct_image_shape, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(BatchNormalization())

x = Dense(128, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))(x)
x = BatchNormalization()(x)

x = Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))(x)
x = BatchNormalization()(x)

x = Dense(64, activation='relu',kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))(x)
x = BatchNormalization()(x)

x = Dense(32, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))(x)
x = BatchNormalization()(x)

model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  batch_normalization (BatchN  (None, 222, 222, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 109, 109, 32)     128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 52, 52, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  batch_normalization_4 (Batc  (None, 9216)             36864
#  hNormalization)
#
#  dense (Dense)               (None, 128)               1179776
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  batch_normalization_7 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_3 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 1,294,538
# Trainable params: 1,275,274
# Non-trainable params: 19,264
# _________________________________________________________________

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(learning_rate=2e-5), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 181s 255ms/step - loss: 1.8965 - accuracy: 0.3728 - val_loss: 1.6772 - val_accuracy: 0.4420
# Epoch 2/30
# 625/625 [==============================] - 144s 231ms/step - loss: 1.3615 - accuracy: 0.5560 - val_loss: 1.0779 - val_accuracy: 0.6600
# Epoch 3/30
# 625/625 [==============================] - 154s 246ms/step - loss: 1.1561 - accuracy: 0.6348 - val_loss: 0.9046 - val_accuracy: 0.7380
# Epoch 4/30
# 625/625 [==============================] - 154s 246ms/step - loss: 1.0249 - accuracy: 0.6819 - val_loss: 0.8156 - val_accuracy: 0.7640
# Epoch 5/30
# 625/625 [==============================] - 145s 231ms/step - loss: 0.9424 - accuracy: 0.7092 - val_loss: 0.6954 - val_accuracy: 0.8040
# Epoch 6/30
# 625/625 [==============================] - 155s 248ms/step - loss: 0.8753 - accuracy: 0.7382 - val_loss: 0.6901 - val_accuracy: 0.8050
# Epoch 7/30
# 625/625 [==============================] - 172s 274ms/step - loss: 0.7834 - accuracy: 0.7691 - val_loss: 0.6054 - val_accuracy: 0.8370
# Epoch 8/30
# 625/625 [==============================] - 189s 303ms/step - loss: 0.7506 - accuracy: 0.7777 - val_loss: 0.5371 - val_accuracy: 0.8550
# Epoch 9/30
# 625/625 [==============================] - 183s 292ms/step - loss: 0.7015 - accuracy: 0.7847 - val_loss: 0.5212 - val_accuracy: 0.8500
# Epoch 10/30
# 625/625 [==============================] - 387s 621ms/step - loss: 0.6565 - accuracy: 0.8084 - val_loss: 0.4934 - val_accuracy: 0.8660
# Epoch 11/30
# 625/625 [==============================] - 151s 242ms/step - loss: 0.6215 - accuracy: 0.8132 - val_loss: 0.4596 - val_accuracy: 0.8690
# Epoch 12/30
# 625/625 [==============================] - 145s 231ms/step - loss: 0.6092 - accuracy: 0.8158 - val_loss: 0.4204 - val_accuracy: 0.8830
# Epoch 13/30
# 625/625 [==============================] - 143s 229ms/step - loss: 0.5702 - accuracy: 0.8340 - val_loss: 0.3663 - val_accuracy: 0.8840
# Epoch 14/30
# 625/625 [==============================] - 144s 230ms/step - loss: 0.5565 - accuracy: 0.8310 - val_loss: 0.4066 - val_accuracy: 0.8840
# Epoch 15/30
# 625/625 [==============================] - 143s 229ms/step - loss: 0.5246 - accuracy: 0.8428 - val_loss: 0.5020 - val_accuracy: 0.8430
# Epoch 16/30
# 625/625 [==============================] - 144s 230ms/step - loss: 0.5068 - accuracy: 0.8523 - val_loss: 0.3410 - val_accuracy: 0.9070
# Epoch 17/30
# 625/625 [==============================] - 149s 238ms/step - loss: 0.4886 - accuracy: 0.8566 - val_loss: 0.3338 - val_accuracy: 0.9020
# Epoch 18/30
# 625/625 [==============================] - 146s 234ms/step - loss: 0.4680 - accuracy: 0.8618 - val_loss: 0.3099 - val_accuracy: 0.9100
# Epoch 19/30
# 625/625 [==============================] - 146s 233ms/step - loss: 0.4540 - accuracy: 0.8645 - val_loss: 0.2880 - val_accuracy: 0.9210
# Epoch 20/30
# 625/625 [==============================] - 144s 230ms/step - loss: 0.4330 - accuracy: 0.8654 - val_loss: 0.3049 - val_accuracy: 0.9020
# Epoch 21/30
# 625/625 [==============================] - 145s 231ms/step - loss: 0.4231 - accuracy: 0.8719 - val_loss: 0.2724 - val_accuracy: 0.9220
# Epoch 22/30
# 625/625 [==============================] - 144s 231ms/step - loss: 0.4108 - accuracy: 0.8751 - val_loss: 0.2966 - val_accuracy: 0.9020
# Epoch 23/30
# 625/625 [==============================] - 145s 231ms/step - loss: 0.4016 - accuracy: 0.8798 - val_loss: 0.2639 - val_accuracy: 0.9260
# Epoch 24/30
# 625/625 [==============================] - 146s 234ms/step - loss: 0.3910 - accuracy: 0.8808 - val_loss: 0.2700 - val_accuracy: 0.9300
# Epoch 25/30
# 625/625 [==============================] - 145s 232ms/step - loss: 0.3900 - accuracy: 0.8844 - val_loss: 0.2488 - val_accuracy: 0.9280
# Epoch 26/30
# 625/625 [==============================] - 143s 228ms/step - loss: 0.3612 - accuracy: 0.8921 - val_loss: 0.2642 - val_accuracy: 0.9280
# Epoch 27/30
# 625/625 [==============================] - 144s 230ms/step - loss: 0.3494 - accuracy: 0.8952 - val_loss: 0.2840 - val_accuracy: 0.9150
# Epoch 28/30
# 625/625 [==============================] - 143s 229ms/step - loss: 0.3590 - accuracy: 0.8891 - val_loss: 0.2014 - val_accuracy: 0.9390
# Epoch 29/30
# 625/625 [==============================] - 144s 230ms/step - loss: 0.3400 - accuracy: 0.8998 - val_loss: 0.2454 - val_accuracy: 0.9300
# Epoch 30/30
# 625/625 [==============================] - 145s 231ms/step - loss: 0.3292 - accuracy: 0.9020 - val_loss: 0.2091 - val_accuracy: 0.9380

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Calculating the accuracy on training and testing data

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 625/625 [==============================] - 139s 222ms/step - loss: 0.1657 - accuracy: 0.9557
# 0.9556999802589417

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 63/63 [==============================] - 13s 211ms/step - loss: 0.2084 - accuracy: 0.9300
# 0.9300000071525574

# %% [markdown]
# ## Making prediction on sample data

# %%
sample_img_load = image.load_img('./tomato_dataset/test/Tomato___Tomato_mosaic_virus/00c07a77-15e6-4815-92d4-8d1e1afb7f3c___PSU_CG 2052.JPG', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load) / 255

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'Tomato___Tomato_mosaic_virus'

# %% [markdown]
# ## Save the model

# %%
save_model(model, 'cnnfromscratch_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cnnfromscratch_model\assets
# INFO:tensorflow:Assets written to: cnnfromscratch_model\assets
