# %% [markdown]
# ## Importing all the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import Dense, BatchNormalization, Flatten
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the tomato dataset

# %%
dataset_directory_location = 'tomato_dataset'

# %% [markdown]
# ## Listing the directories present inside tomato dataset

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %% [markdown]
# ## Getting the training and testing directory location

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %% [markdown]
# ## Listing all the directories present inside 'train' and 'test' directory respectively

# %%
os.listdir(train_dataset_location)
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
os.listdir(test_dataset_location)
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %% [markdown]
# ## Viewing a 'tomato image with bacterial spot image'

# %%
tomato_bacterial_spot_img = os.path.join(train_dataset_location, 'Tomato___Bacterial_spot')

# %%
os.listdir(tomato_bacterial_spot_img)[:1]
# Out:
# ['00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG']

# %%
tomato_bacterial_spot_img_read = imread(os.path.join(tomato_bacterial_spot_img, '00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG'))

# %%
plt.imshow(tomato_bacterial_spot_img_read)

# %% [markdown]
# ## Getting the shape of the image

# %%
tomato_bacterial_spot_img_read.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Setting the right image shape of the image for our use case

# %%
correct_image_shape = (224, 224, 3)

# %% [markdown]
# ## Performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               preprocessing_function=preprocess_input)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
vgg19_model = VGG19(weights='imagenet', include_top=False, input_shape=correct_image_shape)

# %%
vgg19_model.trainable = False

# %%
model.add(vgg19_model)


model.add(Flatten())


model.add(BatchNormalization())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten (Flatten)           (None, 25088)             0
#
#  batch_normalization (BatchN  (None, 25088)            100352
#  ormalization)
#
#  dense (Dense)               (None, 128)               3211392
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_3 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 23,347,690
# Trainable params: 3,272,682
# Non-trainable params: 20,075,008
# _________________________________________________________________

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 187s 259ms/step - loss: 0.9368 - accuracy: 0.6953 - val_loss: 0.6477 - val_accuracy: 0.7990
# Epoch 2/30
# 625/625 [==============================] - 153s 245ms/step - loss: 0.5250 - accuracy: 0.8270 - val_loss: 0.5302 - val_accuracy: 0.8350
# Epoch 3/30
# 625/625 [==============================] - 162s 258ms/step - loss: 0.4308 - accuracy: 0.8560 - val_loss: 0.4802 - val_accuracy: 0.8460
# Epoch 4/30
# 625/625 [==============================] - 155s 248ms/step - loss: 0.3762 - accuracy: 0.8737 - val_loss: 0.4662 - val_accuracy: 0.8550
# Epoch 5/30
# 625/625 [==============================] - 148s 236ms/step - loss: 0.3322 - accuracy: 0.8889 - val_loss: 0.4439 - val_accuracy: 0.8580
# Epoch 6/30
# 625/625 [==============================] - 148s 237ms/step - loss: 0.3089 - accuracy: 0.8983 - val_loss: 0.4306 - val_accuracy: 0.8700
# Epoch 7/30
# 625/625 [==============================] - 147s 235ms/step - loss: 0.2896 - accuracy: 0.9024 - val_loss: 0.4508 - val_accuracy: 0.8640
# Epoch 8/30
# 625/625 [==============================] - 149s 238ms/step - loss: 0.2794 - accuracy: 0.9044 - val_loss: 0.4560 - val_accuracy: 0.8660
# Epoch 9/30
# 625/625 [==============================] - 148s 236ms/step - loss: 0.2649 - accuracy: 0.9083 - val_loss: 0.4416 - val_accuracy: 0.8670
# Epoch 10/30
# 625/625 [==============================] - 148s 237ms/step - loss: 0.2462 - accuracy: 0.9175 - val_loss: 0.4044 - val_accuracy: 0.8730
# Epoch 11/30
# 625/625 [==============================] - 150s 239ms/step - loss: 0.2319 - accuracy: 0.9227 - val_loss: 0.4193 - val_accuracy: 0.8790
# Epoch 12/30
# 625/625 [==============================] - 148s 237ms/step - loss: 0.2234 - accuracy: 0.9231 - val_loss: 0.4940 - val_accuracy: 0.8700
# Epoch 13/30
# 625/625 [==============================] - 147s 234ms/step - loss: 0.2232 - accuracy: 0.9239 - val_loss: 0.4234 - val_accuracy: 0.8810
# Epoch 14/30
# 625/625 [==============================] - 150s 240ms/step - loss: 0.2146 - accuracy: 0.9280 - val_loss: 0.4534 - val_accuracy: 0.8750
# Epoch 15/30
# 625/625 [==============================] - 148s 236ms/step - loss: 0.1993 - accuracy: 0.9334 - val_loss: 0.3866 - val_accuracy: 0.8880
# Epoch 16/30
# 625/625 [==============================] - 149s 238ms/step - loss: 0.1994 - accuracy: 0.9328 - val_loss: 0.4336 - val_accuracy: 0.8810
# Epoch 17/30
# 625/625 [==============================] - 147s 235ms/step - loss: 0.1757 - accuracy: 0.9414 - val_loss: 0.4157 - val_accuracy: 0.8880
# Epoch 18/30
# 625/625 [==============================] - 149s 238ms/step - loss: 0.1869 - accuracy: 0.9389 - val_loss: 0.3927 - val_accuracy: 0.8940
# Epoch 19/30
# 625/625 [==============================] - 147s 236ms/step - loss: 0.1690 - accuracy: 0.9423 - val_loss: 0.4516 - val_accuracy: 0.8950
# Epoch 20/30
# 625/625 [==============================] - 148s 237ms/step - loss: 0.1587 - accuracy: 0.9475 - val_loss: 0.4046 - val_accuracy: 0.8940
# Epoch 21/30
# 625/625 [==============================] - 152s 243ms/step - loss: 0.1636 - accuracy: 0.9450 - val_loss: 0.4600 - val_accuracy: 0.8860
# Epoch 22/30
# 625/625 [==============================] - 149s 238ms/step - loss: 0.1525 - accuracy: 0.9493 - val_loss: 0.3686 - val_accuracy: 0.9000
# Epoch 23/30
# 625/625 [==============================] - 150s 240ms/step - loss: 0.1579 - accuracy: 0.9445 - val_loss: 0.4459 - val_accuracy: 0.8910
# Epoch 24/30
# 625/625 [==============================] - 151s 241ms/step - loss: 0.1466 - accuracy: 0.9512 - val_loss: 0.4099 - val_accuracy: 0.8910
# Epoch 25/30
# 625/625 [==============================] - 161s 257ms/step - loss: 0.1420 - accuracy: 0.9512 - val_loss: 0.4321 - val_accuracy: 0.8910
# Epoch 26/30
# 625/625 [==============================] - 150s 239ms/step - loss: 0.1414 - accuracy: 0.9512 - val_loss: 0.4306 - val_accuracy: 0.8920
# Epoch 27/30
# 625/625 [==============================] - 148s 236ms/step - loss: 0.1378 - accuracy: 0.9532 - val_loss: 0.4250 - val_accuracy: 0.8970
# Epoch 28/30
# 625/625 [==============================] - 151s 241ms/step - loss: 0.1289 - accuracy: 0.9549 - val_loss: 0.3920 - val_accuracy: 0.9000
# Epoch 29/30
# 625/625 [==============================] - 157s 251ms/step - loss: 0.1306 - accuracy: 0.9582 - val_loss: 0.3887 - val_accuracy: 0.9050
# Epoch 30/30
# 625/625 [==============================] - 163s 261ms/step - loss: 0.1285 - accuracy: 0.9600 - val_loss: 0.4391 - val_accuracy: 0.8910

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Calculating the accuracy on training and testing data

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 625/625 [==============================] - 142s 226ms/step - loss: 0.0825 - accuracy: 0.9731
# 0.9731000065803528

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 63/63 [==============================] - 14s 226ms/step - loss: 0.4185 - accuracy: 0.8960
# 0.8960000276565552

# %% [markdown]
# ## Making prediction on sample data

# %%
sample_img_load = image.load_img('./tomato_dataset/test/Tomato___Target_Spot/0a3b6099-c254-4bc3-8360-53a9f558a0c4___Com.G_TgS_FL 8259.JPG', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load)

# %%
sample_img_to_arr_preprocess_input = preprocess_input(sample_img_to_arr)

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr_preprocess_input, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'Tomato___Target_Spot'

# %% [markdown]
# ## Saving the model

# %%
save_model(model, 'VGG19_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: VGG19_model\assets
# INFO:tensorflow:Assets written to: VGG19_model\assets
